# %% [markdown]
# # Reduce the number of colors of any jpg image
#
# Given a jpg image, could you average the colors, so you end up with a new image with less colors?
#
# I would recommend you load a .jpg image with matplotlib and estimate the optimal clusters of the the present colors (3 bands RGB) before reducing them to a smaller number of colors.
#
# **Below you can find an image to start with.**
#
# ## Load data

# %%
import numpy as np
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# %%
def load_image_from_url(img_url:str) -> np.ndarray:
    """
    Loads an image from the specified URL and converts it to an RGB format numpy array.
    
    This function fetches an image from a given URL using the requests library, opens it with PIL (Python Imaging Library),
    converts the image to RGB format to ensure consistency, and then converts it to a numpy array for further processing.
    
    Parameters:
    - img_url (str): The URL of the image to load.
    
    Returns:
    - numpy.ndarray: An array representation of the image in RGB format.
    """
    # Fetch the image from the URL
    response = requests.get(img_url)
    # Open the image using PIL and ensure it is in RGB
    image = Image.open(BytesIO(response.content)).convert('RGB')

    return np.array(image)

# %%
# Image link
img_url = 'https://fcb-abj-pre.s3.amazonaws.com/img/jugadors/501_maradona.jpg'
# Load data from URL
img_array = load_image_from_url(img_url)

# %%
# Display the image using matplotlib with title and axes
plt.imshow(img_array)
plt.title('Image from Array')
plt.xlabel('Pixel X')
plt.ylabel('Pixel Y')
plt.axis('on')  # Use 'off' to turn off axis numbers and ticks
plt.subplots_adjust(bottom=0.13) # Adjust the subplot parameters to give more space at the bottom
plt.figtext(0.5, 0.01, f'Shape of array: {img_array.shape}', ha="center", fontsize=8, color='gray') # Add a footnote with the shape of the array
plt.show()

# %% [markdown]
# ## Number of cluster estimation

# %%
# Type your code here:

# %% [markdown]
# ## Image color reduction

# %%
# Type your code here:
